# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
athlete_data = pd.read_csv('Athletes.csv')
coach_data = pd.read_csv('Coaches.csv')
gender_data = pd.read_csv('EntriesGender.csv')
medal_data = pd.read_csv('Medals.csv')
team_data = pd.read_csv('Teams.csv')

# %%
athlete_data.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
gender_data.head()
# Out:
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# 3    Artistic Swimming     105     0    105
# 4            Athletics     969  1072   2041

# %%
medal_data.head()
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
team_data.head()
# Out:
#       Name      Discipline                         NOC  Event
# 0  Belgium  3x3 Basketball                     Belgium    Men
# 1    China  3x3 Basketball  People's Republic of China    Men
# 2    China  3x3 Basketball  People's Republic of China  Women
# 3   France  3x3 Basketball                      France  Women
# 4    Italy  3x3 Basketball                       Italy  Women

# %%
athlete_data.isnull().sum()
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %%
gender_data.isnull().sum()
# Out:
# Discipline    0
# Female        0
# Male          0
# Total         0
# dtype: int64

# %%
medal_data.isnull().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold             0
# Silver           0
# Bronze           0
# Total            0
# Rank by Total    0
# dtype: int64

# %%
coach_data.isnull().sum()
# Out:
# Name            0
# NOC             0
# Discipline      0
# Event         145
# dtype: int64

# %% [markdown]
#  # Which countries do most athlete's come from?

# %%
athlete_data.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
athlete_data['NOC'].value_counts()
# Out:
# United States of America       615
# Japan                          586
# Australia                      470
# People's Republic of China     401
# Germany                        400
#                               ...
# United Republic of Tanzania      2
# Saint Kitts and Nevis            2
# Marshall Islands                 2
# Vanuatu                          2
# South Sudan                      2
# Name: NOC, Length: 206, dtype: int64

# %%
y = athlete_data.NOC.value_counts().values[:30]
x = athlete_data.NOC.value_counts().index[:30]
plt.figure(figsize=(20,4))
plt.bar(x,y)
plt.xlabel("Country")
plt.ylabel("Number of athelets")
plt.xticks(rotation="vertical",size=12)
plt.yticks(size=16)
plt.show()

# %% [markdown]
# # Which Discipline is most popular and which country has the highest participants in it?

# %%
athlete_data.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
athlete_data["Discipline"].value_counts()[:15]
# Out:
# Athletics       2068
# Swimming         743
# Football         567
# Rowing           496
# Hockey           406
# Judo             373
# Handball         343
# Shooting         342
# Sailing          336
# Rugby Sevens     283
# Basketball       280
# Wrestling        279
# Volleyball       274
# Boxing           270
# Water Polo       269
# Name: Discipline, dtype: int64

# %%
y = athlete_data.Discipline.value_counts().values
x = athlete_data.Discipline.value_counts().index
plt.figure(figsize=(20,4))
for index,value in enumerate(y):
    plt.text(index,value,str(value),color = "blue",size = 12)
    
plt.bar(x,y)
plt.xlabel("Discipline")
plt.ylabel("Number of athelets")
plt.xticks(rotation="vertical",size=12)
plt.yticks(size=16)
plt.show()

# %%
athlete_datas = team_data[(team_data["Discipline"]=="Athletics")]
athlete_datas["NOC"].value_counts()
# Out:
# United States of America      5
# Germany                       5
# Italy                         5
# Netherlands                   5
# Great Britain                 5
# Jamaica                       5
# Poland                        4
# France                        4
# Trinidad and Tobago           3
# Japan                         3
# Brazil                        3
# Belgium                       3
# Canada                        2
# People's Republic of China    2
# Switzerland                   2
# South Africa                  2
# Nigeria                       2
# India                         2
# Ukraine                       2
# Denmark                       2
# Spain                         1
# Turkey                        1
# Australia                     1
# Ireland                       1
# Bahamas                       1
# Ecuador                       1
# Dominican Republic            1
# Czech Republic                1
# Cuba                          1
# Colombia                      1
# Botswana                      1
# Belarus                       1
# Ghana                         1
# Name: NOC, dtype: int64

# %% [markdown]
# # Which country produces highest number of coaches?

# %%
coach_data.isnull().sum()
# Out:
# Name            0
# NOC             0
# Discipline      0
# Event         145
# dtype: int64

# %%
coach_data.NOC.value_counts()
# Out:
# Japan                       35
# United States of America    28
# Spain                       28
# Australia                   22
# Canada                      16
#                             ..
# Portugal                     1
# Belarus                      1
# Slovakia                     1
# Croatia                      1
# Liechtenstein                1
# Name: NOC, Length: 61, dtype: int64

# %% [markdown]
# # Gender across disciplines.

# %%
gender_data.head()
# Out:
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# 3    Artistic Swimming     105     0    105
# 4            Athletics     969  1072   2041

# %%
gender_data.isnull().sum()
# Out:
# Discipline    0
# Female        0
# Male          0
# Total         0
# dtype: int64

# %%
Disc = gender_data.groupby("Discipline")
x = [Discipline for Discipline,df in Disc]
female = gender_data.Female
male = gender_data.Male
plt.figure(figsize=(20,8))
x_axis = np.arange(len(x))
plt.bar(x_axis-0.2,female,0.4,label = "female")
plt.bar(x_axis+0.2,male,0.4,label = "male")
plt.ylabel("Number of Participants")
plt.xticks(x_axis,x,rotation="vertical")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Which country received most gold medal ?	Which received most silver and most bronze and which received least for each?

# %%
medal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           93 non-null     int64
#  1   Team/NOC       93 non-null     object
#  2   Gold           93 non-null     int64
#  3   Silver         93 non-null     int64
#  4   Bronze         93 non-null     int64
#  5   Total          93 non-null     int64
#  6   Rank by Total  93 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
x = []
for team in medal_data["Team/NOC"]:
     x.append(team)
y = medal_data.Gold
plt.figure(figsize=(20,10))
plt.bar(x,y)
for index,value in enumerate(y):
    plt.text(index,value,str(value),color="Red",size=10)
plt.xlabel("Country")
plt.ylabel("Gold Medals")
plt.xticks(x,rotation = "vertical")
plt.title("Gold Medals across Nations")
plt.show()

# %%
x = []
for team in medal_data["Team/NOC"]:
     x.append(team)
y = medal_data.Silver
plt.figure(figsize=(20,10))
plt.bar(x,y)
for index,value in enumerate(y):
    plt.text(index,value,str(value),color="Red",size=10)
plt.xlabel("Country")
plt.ylabel("Silver Medals")
plt.xticks(x,rotation = "vertical")
plt.title("Silver Medals across Nations")
plt.show()

# %%
x = []
for team in medal_data["Team/NOC"]:
     x.append(team)
y = medal_data.Bronze         
plt.figure(figsize=(20,10))
plt.bar(x,y)
for index,value in enumerate(y):
    plt.text(index,value,str(value),color="Red",size=10)
plt.xlabel("Country")
plt.ylabel("Bronze Medals")
plt.xticks(x,rotation = "vertical")
plt.title("Bronze Medals across Nations")
plt.show()

# %%
x = []
for team in medal_data["Team/NOC"]:
     x.append(team)
y = medal_data.Total         
plt.figure(figsize=(20,10))
plt.bar(x,y)
for index,value in enumerate(y):
    plt.text(index,value,str(value),color="Red",size=10)
plt.xlabel("Country")
plt.ylabel("Total Medals")
plt.xticks(x,rotation = "vertical")
plt.title("Total Medals across Nations")
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\mssin\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\mssin\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in c:\users\mssin\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mssin\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\mssin\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mssin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mssin\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\mssin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
